# %%
# Creating my own dataset for training a model to predict the winning combinations of a dice game like ludo
import random
import pandas as pd
# Simulate ludo for 4 players
def simulate_ludo(num_games=20):
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Creating my own dataset for training a model to predict the winning combinations of a dice game like ludo
#       2 import random
# ----> 3 import pandas as pd
#       4 def simulate_dice_game(num_simulations=20):
#       5     data = []
#
# ModuleNotFoundError: No module named 'pandas'
